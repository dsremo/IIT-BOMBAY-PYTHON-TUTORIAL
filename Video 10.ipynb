# %% [markdown]
# # Video 10

# %%
'''Outline:
scatter plot
scatter function
scatter plot with various arguments
logarithmic plot
loglog function
cat command
loadtxt function
unpack parameter of loadtxt
linspace
scatter versus plot'''
# Out:
# 'Outline:\nscatter plot\nscatter function\nscatter plot with various arguments\nlogarithmic plot\nloglog function\ncat command\nloadtxt function\nunpack parameter of loadtxt\nlinspace\nscatter versus plot'

# %%
import pylab as pb
from pylab import linspace, plot, cos, sin
from math import pi

# %%
! type company-a-data.txt
# Out:
# 2.000000000000000000e+03 2.300000000000000000e+01
# 2.001000000000000000e+03 5.500000000000000000e+01
# 2.002000000000000000e+03 3.200000000000000000e+01
# 2.003000000000000000e+03 6.500000000000000000e+01
# 2.004000000000000000e+03 8.800000000000000000e+01
# 2.005000000000000000e+03 5.000000000000000000e+00
# 2.006000000000000000e+03 1.400000000000000000e+01
# 2.007000000000000000e+03 6.700000000000000000e+01
# 2.008000000000000000e+03 2.300000000000000000e+01
# 2.009000000000000000e+03 2.300000000000000000e+01
# 2.010000000000000000e+03 1.200000000000000000e+01

# %%
# Assignment
year, profit = pb.loadtxt('company-a-data.txt', unpack = True)

# %%
pb.scatter(year,profit,color='r',marker = 'd')

# %%
pb.scatter(year,profit,color='r',marker = 'x')
#help('pylab.scatter')

# %%
x = linspace(1,20,20)

# %%
y = 5*x**3

# %%
pb.loglog(x,y)

# %%
# Assignment
# 1. scatter(x, y, color=’blue’, marker=’d’) and plot(x, y, color=’b’, marker=’d’) does exactly the same?
#➢ True or False
# Ans: False
plot(x, y, color='b', marker='d')

# %%
pb.scatter(x, y, color='blue', marker='d')
