# %% [markdown]
# # Video 6

# %%
import pylab as pb
from pylab import linspace, plot, cos, sin
from math import pi

# %%
x = linspace(0,50,500)

# %%
plot(x,cos(x))
y = linspace(0,5,100)
plot(y,y**2)

# %%
pb.subplot(2,1,1)
plot(x,cos(x))
pb.subplot(2,1,2)
plot(y,y**2)

# %%
# Assignment
v = linspace(21,100,500)
pb.subplot(2,1,1)
plot(v,2.0/v)# nRT is constant and we know nR = 0.01 and T = 200 and relation is pV = nRT
pb.title('Pressure Vs Volume')

pb.subplot(2,1,2)
#plot(200,2.0/v) #error of dimension
t = linspace(200,200,500)
plot(t,2.0/v)
pb.title('Pressure Vs Temperature')
# Out:
# Text(0.5, 1.0, 'Pressure Vs Temperature')

# %%
# Which of the following is correct?
#1. subplot (numRows, numCols, plotNum)
