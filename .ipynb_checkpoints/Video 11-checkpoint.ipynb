# %% [markdown]
# # Video 11

# %%
'''* Plot a pie chart using pie() function
* Plot a bar chart using bar() function
* Access the matplotlib online help
* Charts with line hatching'''
# Out:
# '* Plot a pie chart using pie() function\n* Plot a bar chart using bar() function\n* Access the matplotlib online help\n* Charts with line hatching'

# %%
import pylab as pb
from pylab import linspace, plot, cos, sin,pie
from math import pi

# %%
! type company-a-data.txt
# Out:
# 2.000000000000000000e+03 2.300000000000000000e+01
# 2.001000000000000000e+03 5.500000000000000000e+01
# 2.002000000000000000e+03 3.200000000000000000e+01
# 2.003000000000000000e+03 6.500000000000000000e+01
# 2.004000000000000000e+03 8.800000000000000000e+01
# 2.005000000000000000e+03 5.000000000000000000e+00
# 2.006000000000000000e+03 1.400000000000000000e+01
# 2.007000000000000000e+03 6.700000000000000000e+01
# 2.008000000000000000e+03 2.300000000000000000e+01
# 2.009000000000000000e+03 2.300000000000000000e+01
# 2.010000000000000000e+03 1.200000000000000000e+01

# %%
year, profit = pb.loadtxt("company-a-data.txt",unpack = True)

# %%
pie(profit,labels = year)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c7246b0790>,
# ...
#  [Text(1.082710267240562, 0.19426393698232036, '2000.0'),
#   Text(0.7823073407063368, 0.7733015095530201, '2001.0'),
#   Text(0.1312935560403258, 1.0921364393436774, '2002.0'),
#   Text(-0.6472504641020703, 0.889419381798966, '2003.0'),
#   Text(-1.0686582162250247, -0.26070983275424914, '2004.0'),
#   Text(-0.6334432490362563, -0.8993050929747878, '2005.0'),
#   Text(-0.495224127532519, -0.9822184398134945, '2006.0'),
#   Text(0.1733357178535357, -1.0862572112148208, '2007.0'),
#   Text(0.8285381872666441, -0.7235499099861071, '2008.0'),
#   Text(1.0284020073873785, -0.3903707355855592, '2009.0'),
#   Text(1.0952845205026953, -0.10174388997468571, '2010.0')])

# %%
# Assignment
#help('pylab.pie')
# pylab.pie = pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, 
# labeldistance=1.1, startangle=None, radius=None, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), 
#frame=False, rotatelabels=False, *, data=None)
pie(profit,labels = year,colors = ('w','r','k','m','y','b','g','c','y','m','b'))
# Out:
# ([<matplotlib.patches.Wedge at 0x1c724a22af0>,
# ...
#  [Text(1.082710267240562, 0.19426393698232036, '2000.0'),
#   Text(0.7823073407063368, 0.7733015095530201, '2001.0'),
#   Text(0.1312935560403258, 1.0921364393436774, '2002.0'),
#   Text(-0.6472504641020703, 0.889419381798966, '2003.0'),
#   Text(-1.0686582162250247, -0.26070983275424914, '2004.0'),
#   Text(-0.6334432490362563, -0.8993050929747878, '2005.0'),
#   Text(-0.495224127532519, -0.9822184398134945, '2006.0'),
#   Text(0.1733357178535357, -1.0862572112148208, '2007.0'),
#   Text(0.8285381872666441, -0.7235499099861071, '2008.0'),
#   Text(1.0284020073873785, -0.3903707355855592, '2009.0'),
#   Text(1.0952845205026953, -0.10174388997468571, '2010.0')])

# %%
pb.bar(year,profit)
# Out:
# <BarContainer object of 11 artists>

# %%
# Assignment
# help('pylab.bar')
pb.bar(year,profit,fill=False,hatch = '/')
# Out:
# <BarContainer object of 11 artists>

# %%
# help('pylab.bar')
pb.bar(year,profit,fill=False,hatch = '+')
# Out:
# <BarContainer object of 11 artists>

# %%
# help('pylab.bar')
pb.bar(year,profit,fill=False,hatch = '|')
# Out:
# <BarContainer object of 11 artists>

# %%
# help('pylab.bar')
pb.bar(year,profit,fill=False,hatch = '-')
# Out:
# <BarContainer object of 11 artists>

# %%
# help('pylab.bar')
pb.bar(year,profit,fill=False,hatch = '*')
# Out:
# <BarContainer object of 11 artists>
